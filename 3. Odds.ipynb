# %%
import os, json
import pandas as pd
import numpy as np

# %%
years = [year for year in range(2016,2022+1)]
odds_dfs = []
for year in years:
    path_str = 'data/Odds/' + str(year) + '/'
    for x, file_name in enumerate([x_json for x_json in os.listdir(path_str) if x_json.endswith('.json')]):
        with open(path_str + file_name) as json_file:
            if x == 0:
                odds_df = pd.DataFrame(json.load(json_file))
            else:
                odds_df = pd.concat([odds_df,pd.DataFrame(json.load(json_file))])
    odds_df['Season'] = year
    odds_dfs.append(odds_df)

# %%
odds_dfs[0]['Favorite'].str[:2]=="at"
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4     False
#       ...
# 8     False
# 9      True
# 10     True
# 11     True
# 12     True
# Name: Favorite, Length: 256, dtype: bool

# %%
odds_dfs[0]['Favorite'].str[2:]
# Out:
# 0        nthers
# 1        Texans
# 2         ngals
# 3        Eagles
# 4         ckers
#         ...
# 8          ints
# 9       Packers
# 10     Chargers
# 11      Raiders
# 12     Seahawks
# Name: Favorite, Length: 256, dtype: object

# %%
full_odds = pd.concat(odds_dfs).reset_index(drop = True)

# %%
full_odds
# Out:
#                             Date       Favorite    UnderDog PointSpread  \
# 0      September 8, 2016 8:30 PM       Panthers  at Broncos        -3.0
# 1     September 11, 2016 1:00 PM      at Texans       Bears        -6.0
# 2     September 11, 2016 1:00 PM        Bengals     at Jets        -3.0
# 3     September 11, 2016 1:00 PM      at Eagles      Browns        -4.0
# 4     September 11, 2016 1:00 PM        Packers  at Jaguars        -6.0
# ...                          ...            ...         ...         ...
# 1744    December 4, 2022 4:05 PM       at 49ers    Dolphins        -4.5
# 1745    December 4, 2022 4:25 PM         Chiefs  at Bengals        -2.0
# 1746    December 4, 2022 4:25 PM     at Raiders    Chargers        -2.5
# 1747    December 4, 2022 8:20 PM     at Cowboys       Colts       -10.5
# 1748    December 5, 2022 8:15 PM  at Buccaneers      Saints        -3.5
#
#      OverUnder AwayTeamMoneyLine HomeTeamMoneyLine  Season
# 0         41.0              -165              +145    2016
# 1         42.5              +220              -260    2016
# 2         42.0              -115              -105    2016
# 3         41.5              +165              -190    2016
# 4         48.0              -210              +175    2016
# ...        ...               ...               ...     ...
# 1744      45.5              +180              -217    2022
# 1745      52.5              -134              +113    2022
# 1746      49.5              +115              -136    2022
# 1747      44.0              +394              -513    2022
# 1748      40.5              +162              -193    2022
#
# [1749 rows x 8 columns]

# %%
full_odds['home_team'] = np.where(full_odds['Favorite'].str[:2]=="at",full_odds['Favorite'].str[3:],full_odds['UnderDog'].str[3:])
full_odds['away_team'] = np.where(full_odds['Favorite'].str[:2]=="at",full_odds['UnderDog'],full_odds['Favorite'])
full_odds['home_fav'] = np.where(full_odds['Favorite'].str[:2]=="at",True,False)

# %%
full_odds['date_match'] = pd.to_datetime(full_odds['Date']).dt.normalize()

# %%
full_odds
# Out:
#                             Date       Favorite    UnderDog PointSpread  \
# 0      September 8, 2016 8:30 PM       Panthers  at Broncos        -3.0
# 1     September 11, 2016 1:00 PM      at Texans       Bears        -6.0
# 2     September 11, 2016 1:00 PM        Bengals     at Jets        -3.0
# 3     September 11, 2016 1:00 PM      at Eagles      Browns        -4.0
# 4     September 11, 2016 1:00 PM        Packers  at Jaguars        -6.0
# ...                          ...            ...         ...         ...
# 1744    December 4, 2022 4:05 PM       at 49ers    Dolphins        -4.5
# 1745    December 4, 2022 4:25 PM         Chiefs  at Bengals        -2.0
# 1746    December 4, 2022 4:25 PM     at Raiders    Chargers        -2.5
# 1747    December 4, 2022 8:20 PM     at Cowboys       Colts       -10.5
# 1748    December 5, 2022 8:15 PM  at Buccaneers      Saints        -3.5
#
#      OverUnder AwayTeamMoneyLine HomeTeamMoneyLine  Season   home_team  \
# 0         41.0              -165              +145    2016     Broncos
# 1         42.5              +220              -260    2016      Texans
# 2         42.0              -115              -105    2016        Jets
# 3         41.5              +165              -190    2016      Eagles
# 4         48.0              -210              +175    2016     Jaguars
# ...        ...               ...               ...     ...         ...
# 1744      45.5              +180              -217    2022       49ers
# 1745      52.5              -134              +113    2022     Bengals
# 1746      49.5              +115              -136    2022     Raiders
# 1747      44.0              +394              -513    2022     Cowboys
# 1748      40.5              +162              -193    2022  Buccaneers
#
#      away_team  home_fav date_match
# 0     Panthers     False 2016-09-08
# 1        Bears      True 2016-09-11
# 2      Bengals     False 2016-09-11
# 3       Browns      True 2016-09-11
# 4      Packers     False 2016-09-11
# ...        ...       ...        ...
# 1744  Dolphins      True 2022-12-04
# 1745    Chiefs     False 2022-12-04
# 1746  Chargers      True 2022-12-04
# 1747     Colts      True 2022-12-04
# 1748    Saints      True 2022-12-05
#
# [1749 rows x 12 columns]

# %%
names_key = ['Broncos', 'Texans', 'Jets', 'Eagles', 'Jaguars', 'Chiefs',
       'Saints', 'Titans', 'Ravens', 'Falcons', 'Seahawks', 'Colts',
       'Cowboys', 'Cardinals', 'Commanders', '49ers', 'Buccaneers',
       'Panthers', 'Chargers', 'Steelers', 'Patriots', 'Giants',
       'Lions', 'Vikings', 'Bengals', 'Browns', 'Rams', 'Raiders',
       'Dolphins', 'Bears', 'Bills', 'Packers']

# %%
abbr_val = ['DEN','HOU','NYJ','PHI','JAX','KC','NO','TEN','BAL','ATL','SEA','IND','DAL','ARI','WAS','SF','TB','CAR','LAC',
           'PIT','NE','NYG','DET','MIN','CIN','CLE','LAR','LV','MIA','CHI','BUF','GB',]

# %%
odds_to_abbr_map = {names_key[i]:abbr_val[i] for i in range(len(names_key))}

# %%
full_odds['home_abbr'] = full_odds['home_team'].map(odds_to_abbr_map)

# %%
full_odds['away_abbr'] = full_odds['away_team'].map(odds_to_abbr_map)

# %%
full_odds.iloc[1263]
#.map(odds_to_abbr_map)
# Out:
# Date                 November 1, 2020 4:05 PM
# Favorite                             Chargers
# UnderDog                           at Broncos
# PointSpread                              -3.0
# OverUnder                                44.0
# AwayTeamMoneyLine                        -178
# HomeTeamMoneyLine                        +147
# Season                                   2020
# home_team                             Broncos
# away_team                            Chargers
# home_fav                                False
# date_match                2020-11-01 00:00:00
# home_abbr                                 DEN
# away_abbr                                 LAC
# Name: 1263, dtype: object

# %%
full_odds['AwayTeamMoneyLine'] = pd.to_numeric(full_odds.AwayTeamMoneyLine)
full_odds['HomeTeamMoneyLine'] = pd.to_numeric(full_odds.HomeTeamMoneyLine)

# %%
full_odds
# Out:
#                             Date       Favorite    UnderDog PointSpread  \
# 0      September 8, 2016 8:30 PM       Panthers  at Broncos        -3.0
# 1     September 11, 2016 1:00 PM      at Texans       Bears        -6.0
# 2     September 11, 2016 1:00 PM        Bengals     at Jets        -3.0
# 3     September 11, 2016 1:00 PM      at Eagles      Browns        -4.0
# 4     September 11, 2016 1:00 PM        Packers  at Jaguars        -6.0
# ...                          ...            ...         ...         ...
# 1744    December 4, 2022 4:05 PM       at 49ers    Dolphins        -4.5
# 1745    December 4, 2022 4:25 PM         Chiefs  at Bengals        -2.0
# 1746    December 4, 2022 4:25 PM     at Raiders    Chargers        -2.5
# 1747    December 4, 2022 8:20 PM     at Cowboys       Colts       -10.5
# 1748    December 5, 2022 8:15 PM  at Buccaneers      Saints        -3.5
#
#      OverUnder  AwayTeamMoneyLine  HomeTeamMoneyLine  Season   home_team  \
# 0         41.0               -165                145    2016     Broncos
# 1         42.5                220               -260    2016      Texans
# 2         42.0               -115               -105    2016        Jets
# 3         41.5                165               -190    2016      Eagles
# 4         48.0               -210                175    2016     Jaguars
# ...        ...                ...                ...     ...         ...
# 1744      45.5                180               -217    2022       49ers
# 1745      52.5               -134                113    2022     Bengals
# 1746      49.5                115               -136    2022     Raiders
# 1747      44.0                394               -513    2022     Cowboys
# 1748      40.5                162               -193    2022  Buccaneers
#
#      away_team  home_fav date_match home_abbr away_abbr
# 0     Panthers     False 2016-09-08       DEN       CAR
# 1        Bears      True 2016-09-11       HOU       CHI
# 2      Bengals     False 2016-09-11       NYJ       CIN
# 3       Browns      True 2016-09-11       PHI       CLE
# 4      Packers     False 2016-09-11       JAX        GB
# ...        ...       ...        ...       ...       ...
# 1744  Dolphins      True 2022-12-04        SF       MIA
# 1745    Chiefs     False 2022-12-04       CIN        KC
# 1746  Chargers      True 2022-12-04        LV       LAC
# 1747     Colts      True 2022-12-04       DAL       IND
# 1748    Saints      True 2022-12-05        TB        NO
#
# [1749 rows x 14 columns]

# %%
full_odds.groupby(['Season'])['Season'].count()
# Out:
# Season
# 2016    256
# 2017    257
# 2018    256
# 2019    256
# 2020    257
# 2021    272
# 2022    195
# Name: Season, dtype: int64

# %%
full_odds.to_csv('data/odds_final.csv')
